# %% [markdown]
# <a href="https://colab.research.google.com/github/NotfromEQ/Step_Up/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test Colab merge in GitHub

# %%
print("Hello World")
# Out:
# Hello World
