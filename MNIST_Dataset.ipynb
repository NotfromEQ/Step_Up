# %% [markdown]
# <a href="https://colab.research.google.com/github/NotfromEQ/Step_Up/blob/Sila_Playground/MNIST_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
digit_dataset= datasets.load_digits()

# %%
print(digit_dataset.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
plt.imshow(digit_dataset.images[0],cmap=plt.get_cmap('PuBu'))
