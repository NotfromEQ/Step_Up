# %% [markdown]
# <a href="https://colab.research.google.com/github/NotfromEQ/Step_Up/blob/Sila_Playground/Iris_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris_dataset=load_iris()

# %%
print(iris_dataset.data.shape)
# Out:
# (150, 4)

# %%
x_train,x_test,y_train,y_test = train_test_split(iris_dataset["data"],iris_dataset["target"],test_size=0.4,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (90, 4)
# (60, 4)
# (90,)
# (60,)
